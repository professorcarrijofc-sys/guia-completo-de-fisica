# %% [markdown]
# # 00_Indice_Geral
#
# Bem-vindo ao Laboratório Interativo de Física - ENEM.
#
# Use este índice para abrir os experimentos por área.

# %% [markdown]
# ## Links internos
# - 01 Mecânica: `01_Mecanica/01_MRU_Movimento_Retilineo_Uniforme.ipynb`
# - 02 Dinâmica: `02_Dinamica/01_Leis_de_Newton.ipynb`
# - 03 Energia: `03_Energia/01_Conservacao_da_Energia_Mecanica.ipynb`
# - 04 Termologia: `04_Termologia/01_Calorimetria_Trocas_de_Calor.ipynb`
# - 05 Ondulatória: `05_Ondulatoria/01_Ondas_Frequencia_e_Comprimento.ipynb`
# - 06 Óptica: `06_Optica/01_Lentes_Delgadas.ipynb`
# - 07 Eletricidade: `07_Eletricidade/01_Lei_de_Ohm_e_Circuito_Simples.ipynb`
